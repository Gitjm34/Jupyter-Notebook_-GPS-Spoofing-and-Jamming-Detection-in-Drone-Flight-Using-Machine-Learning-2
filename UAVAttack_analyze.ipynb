# %%
import os

# 데이터셋 경로 (사용자 환경에 맞게 변경 필요)
dataset_path = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming"

# 각 폴더별 파일 개수 출력
for folder in ["Benign Flight", "GPS Jamming", "GPS Spoofing"]:
    folder_path = os.path.join(dataset_path, folder)
    num_files = len(os.listdir(folder_path))
    print(f"{folder}: {num_files}개의 파일")
# Out:
# Benign Flight: 61개의 파일
# GPS Jamming: 62개의 파일
# GPS Spoofing: 62개의 파일

# %%
import os

# 실제 파일이 있는지 확인할 폴더 경로
folder_path = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming/Benign Flight"

# 폴더 내 파일 목록 출력
file_list = os.listdir(folder_path)
print("📂 Benign Flight 폴더 내 파일 목록:")
for file in file_list:
    print(file)
# Out:
# 📂 Benign Flight 폴더 내 파일 목록:
# ace-benign-log_0_2033-8-19-16-27-30.ulg
# ace-benign-log_0_2033-8-19-16-27-30_actuator_armed_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_actuator_controls_0_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_actuator_outputs_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_actuator_outputs_1.csv
# ace-benign-log_0_2033-8-19-16-27-30_battery_status_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_commander_state_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_cpuload_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_ekf_gps_drift_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_estimator_innovations_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_estimator_innovation_test_ratios_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_estimator_innovation_variances_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_estimator_sensor_bias_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_estimator_status_0.csv
# ace-benign-log_0_2033-8-19-16-27-30_home_position_0.csv
# ...

# %%
import pandas as pd

# Benign Flight 폴더 경로
folder_path = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming/Benign Flight"

# 첫 번째 분석할 파일 선택
file_name = "ace-benign-log_0_2033-8-19-16-27-30_vehicle_global_position_0.csv"
file_path = f"{folder_path}/{file_name}"

# CSV 불러오기
df = pd.read_csv(file_path)

# 데이터 미리보기
print("데이터 미리보기:")
print(df.head())

# 열 정보 확인
print("\n CSV 열 정보:")
print(df.columns)
# Out:
# 📊 데이터 미리보기:
#    timestamp        lat         lon        alt  alt_ellipsoid  delta_alt  \
# 0  615353198  36.204815  138.252922  51.842552      78.012740       -0.0
# 1  615363196  36.204815  138.252922  51.843250      78.013435       -0.0
# 2  615553162  36.204815  138.252922  51.855705      78.027130       -0.0
# 3  615753127  36.204815  138.252922  51.866350      78.038940       -0.0
# 4  615953094  36.204815  138.252922  51.872658      78.046940       -0.0
#
#         eph       epv  terrain_alt  lat_lon_reset_counter  alt_reset_counter  \
# 0  2.794375  4.169183    51.755676                      2                  0
# 1  2.794499  4.169250    51.755860                      2                  0
# 2  2.794452  4.169151    51.767110                      2                  0
# 3  2.794315  4.169039    51.769570                      2                  0
# 4  2.794215  4.169186    51.771595                      2                  0
#
#    terrain_alt_valid  dead_reckoning
# ...

# %%
import matplotlib.pyplot as plt

# 위도(lat) & 경도(lon) 그래프
plt.figure(figsize=(8,6))
plt.plot(df['lon'], df['lat'], marker='o', linestyle='-', markersize=3, label='Flight Path')

plt.xlabel("Longitude (경도)")
plt.ylabel("Latitude (위도)")
plt.title("Drone Flight Path (Benign Flight)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8,6))
plt.plot(df['timestamp'], df['alt'], marker='o', linestyle='-', markersize=2, color='r', label='Altitude')

plt.xlabel("Timestamp (비행 시간)")
plt.ylabel("Altitude (고도, m)")
plt.title("Drone Altitude Over Time (Benign Flight)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
# ...

# %%
# GPS Jamming 폴더 경로
jamming_folder = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming/GPS Jamming"

# 파일명 동일한지 확인
jamming_file = "ace-jamming-log_1_2033-8-19-16-46-46_vehicle_global_position_0.csv"
jamming_path = f"{jamming_folder}/{jamming_file}"

# CSV 파일 불러오기
df_jamming = pd.read_csv(jamming_path)

# 데이터 미리보기
print("📊 GPS Jamming 데이터 미리보기:")
print(df_jamming.head())

# 열 정보 확인
print("\n📌 CSV 열 정보:")
print(df_jamming.columns)
# Out:
# 📊 GPS Jamming 데이터 미리보기:
#    timestamp        lat         lon        alt  alt_ellipsoid  delta_alt  \
# 0  333003247  36.204806  138.252919  44.042625      86.137280       -0.0
# 1  333013247  36.204806  138.252919  44.042667      86.137330       -0.0
# 2  334193134  36.204806  138.252920  44.070393      86.170715       -0.0
# 3  334203108  36.204806  138.252920  44.070755      86.171080       -0.0
# 4  334393050  36.204806  138.252920  44.076202      86.177110       -0.0
#
#         eph       epv  terrain_alt  lat_lon_reset_counter  alt_reset_counter  \
# 0  2.238235  4.370532    43.951717                      2                  0
# 1  2.238366  4.370591    43.951500                      2                  0
# 2  2.237985  4.370538    43.979570                      2                  0
# 3  2.238115  4.370380    43.978275                      2                  0
# 4  2.237962  4.370477    43.980846                      2                  0
#
#    terrain_alt_valid  dead_reckoning
# ...

# %%
import os

# GPS Spoofing 폴더 경로
spoofing_folder = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming/GPS Spoofing"

# 폴더 내 파일 목록 출력
spoofing_files = os.listdir(spoofing_folder)
print("📂 GPS Spoofing 폴더 내 파일 목록:")
for file in spoofing_files:
    print(file)
# Out:
# 📂 GPS Spoofing 폴더 내 파일 목록:
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18.ulg
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_actuator_armed_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_actuator_controls_0_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_actuator_outputs_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_actuator_outputs_1.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_battery_status_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_commander_state_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_cpuload_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_ekf_gps_drift_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_estimator_innovations_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_estimator_innovation_test_ratios_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_estimator_innovation_variances_0.csv
# ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_estimator_sensor_bias_0.csv
# ...

# %%
import pandas as pd

# GPS Spoofing 폴더 경로
spoofing_folder = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming/GPS Spoofing"

# 정확한 파일명
spoofing_file = "ace-spoofing-hackrf-log_5_2033-8-19-17-14-18_vehicle_global_position_0.csv"
spoofing_path = f"{spoofing_folder}/{spoofing_file}"

# CSV 파일 불러오기
df_spoofing = pd.read_csv(spoofing_path)

# 데이터 미리보기
print("📊 GPS Spoofing 데이터 미리보기:")
print(df_spoofing.head())

# 열 정보 확인
print("\n📌 CSV 열 정보:")
print(df_spoofing.columns)
# Out:
# 📊 GPS Spoofing 데이터 미리보기:
#    timestamp        lat         lon        alt  alt_ellipsoid  delta_alt  \
# 0  258842609  36.204812  138.252916  51.336754      86.740776       -0.0
# 1  258852607  36.204812  138.252916  51.336483      86.740510       -0.0
# 2  259042573  36.204812  138.252916  51.332993      86.728030       -0.0
# 3  259252537  36.204812  138.252916  51.330727      86.716736       -0.0
# 4  259452501  36.204812  138.252916  51.329670      86.706880       -0.0
#
#         eph       epv  terrain_alt  lat_lon_reset_counter  alt_reset_counter  \
# 0  2.718645  3.927061    51.236664                      2                  0
# 1  2.718774  3.927111    51.235973                      2                  0
# 2  2.718639  3.927010    51.237175                      2                  0
# 3  2.718602  3.926977    51.239025                      2                  0
# 4  2.718441  3.926896    51.237194                      2                  0
#
#    terrain_alt_valid  dead_reckoning
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

# 정상 비행 궤적 (파란색)
plt.plot(df['lon'], df['lat'], marker='o', linestyle='-', markersize=2, color='blue', label='Benign Flight')

# GPS Jamming 궤적 (빨간색)
plt.plot(df_jamming['lon'], df_jamming['lat'], marker='o', linestyle='-', markersize=2, color='red', label='GPS Jamming')

# GPS Spoofing 궤적 (초록색)
plt.plot(df_spoofing['lon'], df_spoofing['lat'], marker='o', linestyle='-', markersize=2, color='green', label='GPS Spoofing')

plt.xlabel("Longitude (경도)")
plt.ylabel("Latitude (위도)")
plt.title("Drone Flight Path Comparison")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8,6))

# 정상 비행 고도 변화 (파란색)
plt.plot(df['timestamp'], df['alt'], linestyle='-', color='blue', label='Benign Flight')

# GPS Jamming 고도 변화 (빨간색)
plt.plot(df_jamming['timestamp'], df_jamming['alt'], linestyle='-', color='red', label='GPS Jamming')

# GPS Spoofing 고도 변화 (초록색)
plt.plot(df_spoofing['timestamp'], df_spoofing['alt'], linestyle='-', color='green', label='GPS Spoofing')

plt.xlabel("Timestamp (비행 시간)")
plt.ylabel("Altitude (고도, m)")
plt.title("Drone Altitude Comparison Over Time")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
# ...

# %%
plt.figure(figsize=(8,6))

# 수평 오차(eph) 비교
plt.plot(df['timestamp'], df['eph'], linestyle='-', color='blue', label='Benign Flight')
plt.plot(df_jamming['timestamp'], df_jamming['eph'], linestyle='-', color='red', label='GPS Jamming')
plt.plot(df_spoofing['timestamp'], df_spoofing['eph'], linestyle='-', color='green', label='GPS Spoofing')

plt.xlabel("Timestamp (비행 시간)")
plt.ylabel("eph (수평 오차)")
plt.title("Horizontal Position Error (eph) Comparison")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
# ...

# %%
import pandas as pd

# 기본 통계량 확인
print("📌 정상 비행 데이터 (Benign Flight) 통계 요약:\n", df.describe())
print("\n📌 GPS Jamming 데이터 통계 요약:\n", df_jamming.describe())
print("\n📌 GPS Spoofing 데이터 통계 요약:\n", df_spoofing.describe())
# Out:
# 📌 정상 비행 데이터 (Benign Flight) 통계 요약:
#            timestamp          lat          lon          alt  alt_ellipsoid  \
# count  1.232000e+03  1232.000000  1232.000000  1232.000000    1232.000000
# mean   7.382551e+08    36.204820   138.252921    52.579810      76.029384
# std    7.115830e+07     0.000005     0.000003     0.400129       1.008913
# min    6.153532e+08    36.204810   138.252912    51.821846      74.598305
# 25%    6.767068e+08    36.204817   138.252918    52.203728      75.113638
# 50%    7.382529e+08    36.204819   138.252922    52.482285      75.766755
# 75%    7.998069e+08    36.204823   138.252923    52.976932      76.951972
# max    8.613544e+08    36.204830   138.252928    53.263206      78.821260
#
#        delta_alt          eph          epv  terrain_alt  \
# count     1232.0  1232.000000  1232.000000  1232.000000
# mean         0.0     2.816956     4.171680     4.051810
# std          0.0     0.026478     0.002796    14.024099
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
sns.histplot(df['lat'], bins=50, color='blue', label='Benign Flight', kde=True)
sns.histplot(df_jamming['lat'], bins=50, color='red', label='GPS Jamming', kde=True)
sns.histplot(df_spoofing['lat'], bins=50, color='green', label='GPS Spoofing', kde=True)

plt.xlabel("Latitude (위도)")
plt.ylabel("Count")
plt.title("Latitude Distribution Comparison")
plt.legend()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['alt'], bins=50, color='blue', label='Benign Flight', kde=True)
sns.histplot(df_jamming['alt'], bins=50, color='red', label='GPS Jamming', kde=True)
sns.histplot(df_spoofing['alt'], bins=50, color='green', label='GPS Spoofing', kde=True)

plt.xlabel("Altitude (고도, m)")
plt.ylabel("Count")
plt.title("Altitude Distribution Comparison")
plt.legend()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['eph'], bins=50, color='blue', label='Benign Flight', kde=True)
sns.histplot(df_jamming['eph'], bins=50, color='red', label='GPS Jamming', kde=True)
sns.histplot(df_spoofing['eph'], bins=50, color='green', label='GPS Spoofing', kde=True)

plt.xlabel("eph (수평 위치 오차)")
plt.ylabel("Count")
plt.title("Horizontal Position Error (eph) Distribution")
plt.legend()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
# ...

# %%
import numpy as np

# 상관관계 분석
corr_matrix = df[['lat', 'lon', 'alt', 'eph', 'epv']].corr()

# 히트맵 시각화
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Matrix (Benign Flight)")
plt.show()

# %%
import pandas as pd

# 📌 CSV 파일 경로 (경로는 유지)
file_path = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming/Benign Flight/ace-benign-log_0_2033-8-19-16-27-30_vehicle_gps_position_0.csv"

# 📌 데이터 로드
df = pd.read_csv(file_path)

# 📌 컬럼 리스트 출력
print("📌 CSV 파일에 포함된 컬럼 목록:")
print(df.columns.tolist())
# Out:
# 📌 CSV 파일에 포함된 컬럼 목록:
# ['timestamp', 'time_utc_usec', 'lat', 'lon', 'alt', 'alt_ellipsoid', 's_variance_m_s', 'c_variance_rad', 'eph', 'epv', 'hdop', 'vdop', 'noise_per_ms', 'jamming_indicator', 'vel_m_s', 'vel_n_m_s', 'vel_e_m_s', 'vel_d_m_s', 'cog_rad', 'timestamp_time_relative', 'heading', 'heading_offset', 'fix_type', 'vel_ned_valid', 'satellites_used']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 📌 CSV 파일 경로 (경로 유지)
file_path = "C:/Users/user/Desktop/UAVAttackData/Live GPS Spoofing and Jamming/Benign Flight/ace-benign-log_0_2033-8-19-16-27-30_vehicle_gps_position_0.csv"

# 📌 데이터 로드
df = pd.read_csv(file_path)

# 📌 분석할 주요 컬럼 선택
features = ["timestamp", "lat", "lon", "alt", "alt_ellipsoid", "eph", "epv",
            "hdop", "vdop", "noise_per_ms", "jamming_indicator", "vel_m_s",
            "vel_n_m_s", "vel_e_m_s", "vel_d_m_s", "heading", "fix_type", "satellites_used"]

df_selected = df[features]

# 📌 1. 기본 통계 분석
print("📌 기본 통계 분석")
print(df_selected.describe())

# 📌 2. 이상치 탐지 (IQR 방식)
Q1 = df_selected.quantile(0.25)
Q3 = df_selected.quantile(0.75)
IQR = Q3 - Q1
outliers = ((df_selected < (Q1 - 1.5 * IQR)) | (df_selected > (Q3 + 1.5 * IQR))).sum()

print("\n📌 이상치 개수 (IQR 기준)")
print(outliers)

# 📌 3. 분포 시각화 (히스토그램 & KDE)
plt.figure(figsize=(12, 8))
for i, col in enumerate(features[1:]):  # timestamp 제외
    plt.subplot(4, 5, i+1)
    sns.histplot(df_selected[col], kde=True, bins=30)
    plt.title(col)
plt.tight_layout()
plt.show()

# 📌 4. GPS 관련 Feature 비교 (Noise, Jamming, Accuracy)
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_selected[["noise_per_ms", "jamming_indicator", "eph", "epv"]])
plt.title("📌 GPS 신호 품질 및 교란 지표 비교")
plt.grid(True)
plt.show()

# 📌 5. 상관 관계 분석 (Heatmap)
plt.figure(figsize=(10, 8))
sns.heatmap(df_selected.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("📌 Feature Correlation Matrix")
plt.show()
# Out:
# 📌 기본 통계 분석
#           timestamp           lat           lon           alt  alt_ellipsoid  \
# count  2.480000e+02  2.480000e+02  2.480000e+02    248.000000     248.000000
# mean   7.377979e+08  3.620482e+08  1.382529e+09  38810.076613   75906.451613
# std    7.172859e+07  4.838650e+01  3.141030e+01    987.207159     987.179558
# min    6.152911e+08  3.620481e+08  1.382529e+09  37020.000000   74116.000000
# 25%    6.760431e+08  3.620482e+08  1.382529e+09  37979.000000   75075.000000
# 50%    7.377957e+08  3.620482e+08  1.382529e+09  38528.500000   75625.000000
# 75%    7.995499e+08  3.620482e+08  1.382529e+09  39757.500000   76853.500000
# max    8.613020e+08  3.620483e+08  1.382529e+09  41124.000000   78220.000000
#
#               eph         epv        hdop        vdop  noise_per_ms  \
# count  248.000000  248.000000  248.000000  248.000000    248.000000
# mean     2.160383    3.271617    0.772298    1.316613    100.318548
# ...

# %%
print(df_selected.columns)
# Out:
# Index(['timestamp', 'lat', 'lon', 'alt', 'alt_ellipsoid', 'eph', 'epv', 'hdop',
#        'vdop', 'noise_per_ms', 'jamming_indicator', 'vel_m_s', 'vel_n_m_s',
#        'vel_e_m_s', 'vel_d_m_s', 'heading', 'fix_type', 'satellites_used'],
#       dtype='object')

# %%
# 공격 유형을 지정하는 컬럼 추가 (필요 시)
df_selected["attack_type"] = "Benign"  # 예시: 기본적으로 정상 비행으로 설정

# 특정 조건에 따라 공격 유형 지정
df_selected.loc[df_selected["jamming_indicator"] > 0, "attack_type"] = "Jamming"
df_selected.loc[df_selected["noise_per_ms"] > 105, "attack_type"] = "Jamming"
df_selected.loc[df_selected["eph"] > 3.0, "attack_type"] = "Spoofing"

print(df_selected["attack_type"].value_counts())  # 분포 확인
# Out:
# Series([], Name: count, dtype: int64)

# %%
print(df_selected.head())  # 데이터 확인
# Out:
# Empty DataFrame
# Columns: [timestamp, lat, lon, alt, alt_ellipsoid, eph, epv, hdop, vdop, noise_per_ms, jamming_indicator, vel_m_s, vel_n_m_s, vel_e_m_s, vel_d_m_s, heading, fix_type, satellites_used, attack_type]
# Index: []

# %%
# 📌 attack_type 기본값 설정
df_selected["attack_type"] = "Benign"  # 기본적으로 정상 비행으로 설정

# 📌 특정 조건에 따라 공격 유형 지정
df_selected.loc[df_selected["jamming_indicator"] > 0, "attack_type"] = "Jamming"
df_selected.loc[df_selected["noise_per_ms"] > 105, "attack_type"] = "Jamming"
df_selected.loc[df_selected["eph"] > 3.0, "attack_type"] = "Spoofing"

# 📌 변경된 데이터 확인
print(df_selected["attack_type"].value_counts())  # 분포 확인
print(df_selected.head())  # 첫 5개 데이터 확인
# Out:
# Series([], Name: count, dtype: int64)
# Empty DataFrame
# Columns: [timestamp, lat, lon, alt, alt_ellipsoid, eph, epv, hdop, vdop, noise_per_ms, jamming_indicator, vel_m_s, vel_n_m_s, vel_e_m_s, vel_d_m_s, heading, fix_type, satellites_used, attack_type]
# Index: []

# %%
print(df.head())  # 원본 데이터 확인
print(df_selected.head())  # 선택된 데이터 확인
print(df_selected.shape)  # 행과 열 개수 확인
# Out:
#    timestamp     time_utc_usec        lat         lon    alt  alt_ellipsoid  \
# 0  615291088  2008095804600205  362048146  1382529220  40981          78077
# 1  615488043  2008095804800205  362048146  1382529219  40989          78085
# 2  616290101  2008095805600205  362048149  1382529222  41074          78170
# 3  617294720  2008095806600204  362048153  1382529221  41124          78220
# 4  618294293  2008095807600204  362048158  1382529221  41112          78208
#
#    s_variance_m_s  c_variance_rad    eph    epv  ...  vel_n_m_s  vel_e_m_s  \
# 0           0.339        0.756825  1.753  3.074  ...      0.011      0.035
# 1           0.336        0.756826  1.753  3.073  ...     -0.050     -0.020
# 2           0.349        0.756830  1.751  3.070  ...     -0.017      0.000
# 3           0.294        0.756836  1.749  3.065  ...      0.048     -0.002
# 4           0.336        0.756842  1.747  3.061  ...      0.028      0.047
#
# ...

# %%
# 📌 Feature 선택 (dropna 제거)
df_selected = df[["timestamp", "lat", "lon", "alt", "alt_ellipsoid", "eph", "epv",
                  "hdop", "vdop", "noise_per_ms", "jamming_indicator",
                  "vel_m_s", "vel_n_m_s", "vel_e_m_s", "vel_d_m_s",
                  "heading", "fix_type", "satellites_used"]].copy()  # 💡 원본 유지 위해 copy()

# 📌 attack_type 기본값 설정
df_selected["attack_type"] = "Benign"

# 📌 특정 조건에 따라 공격 유형 지정
df_selected.loc[df_selected["jamming_indicator"] > 0, "attack_type"] = "Jamming"
df_selected.loc[df_selected["noise_per_ms"] > 105, "attack_type"] = "Jamming"
df_selected.loc[df_selected["eph"] > 3.0, "attack_type"] = "Spoofing"

# 📌 데이터 확인
print(df_selected["attack_type"].value_counts())  # 각 공격 유형 개수 확인
print(df_selected.head())  # 첫 5개 행 확인
# Out:
# attack_type
# Jamming     241
# Spoofing      7
# Name: count, dtype: int64
#    timestamp        lat         lon    alt  alt_ellipsoid    eph    epv  hdop  \
# 0  615291088  362048146  1382529220  40981          78077  1.753  3.074  0.77
# 1  615488043  362048146  1382529219  40989          78085  1.753  3.073  0.77
# 2  616290101  362048149  1382529222  41074          78170  1.751  3.070  0.77
# 3  617294720  362048153  1382529221  41124          78220  1.749  3.065  0.77
# 4  618294293  362048158  1382529221  41112          78208  1.747  3.061  0.77
#
#    vdop  noise_per_ms  jamming_indicator  vel_m_s  vel_n_m_s  vel_e_m_s  \
# 0  1.35           103                 24    0.036      0.011      0.035
# 1  1.35           103                 24    0.054     -0.050     -0.020
# 2  1.35           103                 27    0.017     -0.017      0.000
# 3  1.35           103                 22    0.048      0.048     -0.002
# ...

# %%
# 📌 Feature 선택
df_selected = df[["timestamp", "lat", "lon", "alt", "alt_ellipsoid", "eph", "epv",
                  "hdop", "vdop", "noise_per_ms", "jamming_indicator",
                  "vel_m_s", "vel_n_m_s", "vel_e_m_s", "vel_d_m_s",
                  "heading", "fix_type", "satellites_used"]].copy()  

# 📌 attack_type 기본값 설정 (모든 데이터를 기본적으로 'Benign'으로 설정)
df_selected["attack_type"] = "Benign"

# 📌 특정 조건에 따라 공격 유형 지정
df_selected.loc[df_selected["jamming_indicator"] > 0, "attack_type"] = "Jamming"
df_selected.loc[df_selected["noise_per_ms"] > 105, "attack_type"] = "Jamming"

# 📌 Spoofing 판단 조건 (eph 값뿐만 아니라 위치 값도 고려)
df_selected.loc[
    (df_selected["eph"] > 3.0) & 
    (df_selected["lat"].diff().abs() > 0.0001) & 
    (df_selected["lon"].diff().abs() > 0.0001), 
    "attack_type"
] = "Spoofing"

# 📌 정상 비행(Benign) 데이터 추가 조건
df_selected.loc[
    (df_selected["jamming_indicator"] == 0) & 
    (df_selected["noise_per_ms"] < 100) & 
    (df_selected["eph"] < 2.0), 
    "attack_type"
] = "Benign"

# 📌 데이터 개수 확인
print(df_selected["attack_type"].value_counts())

# 📌 샘플 데이터 확인
import pandas as pd
import ace_tools as tools  # 데이터 시각화 도구

tools.display_dataframe_to_user(name="Updated Attack Type Data", dataframe=df_selected.head(10))
# Out:
# attack_type
# Jamming     241
# Spoofing      7
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[65], line 35
#      33 # 📌 샘플 데이터 확인
#      34 import pandas as pd
# ---> 35 import ace_tools as tools  # 데이터 시각화 도구
#      37 tools.display_dataframe_to_user(name="Updated Attack Type Data", dataframe=df_selected.head(10))
#
# ModuleNotFoundError: No module named 'ace_tools'

# %%
import os
import subprocess

# 📌 탐색기에서 경로 확인
subprocess.run("explorer", shell=True)
# Out:
# CompletedProcess(args='explorer', returncode=1)
